# %%
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv('D:\Learn Python\sample csv files\matches.csv')

# %%
ipl.shape
# Out:
# (636, 18)

# %%
ipl.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
ipl.head(6)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
ipl.tail(4)
# Out:
#       id  season       city        date                team1  \
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 632  normal           0  Royal Challengers Bangalore            0
# 633  normal           0          Sunrisers Hyderabad           22
# 634  normal           0          Sunrisers Hyderabad            0
# ...

# %%
ipl.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
ipl.iloc[0:5,0:6]                         # i = first letter of ipl (Syntex)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2
# 0  Royal Challengers Bangalore
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4             Delhi Daredevils

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
wbr=ipl["win_by_runs"]

# %%
wbr
# Out:
# 0      35
# 1       0
# 2       0
# 3       0
# 4      15
#        ..
# 631     0
# 632     0
# 633    22
# 634     0
# 635     8
# Name: win_by_runs, Length: 636, dtype: int64

# %%
wbr.describe()
# Out:
# count    636.000000
# mean      13.682390
# std       23.908877
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       20.000000
# max      146.000000
# Name: win_by_runs, dtype: float64

# %%
ipl.loc[0:10,("team1","team2","winner")]
# Out:
#                           team1                        team2  \
# 0           Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                Mumbai Indians       Rising Pune Supergiant
# 2                 Gujarat Lions        Kolkata Knight Riders
# 3        Rising Pune Supergiant              Kings XI Punjab
# 4   Royal Challengers Bangalore             Delhi Daredevils
# 5                 Gujarat Lions          Sunrisers Hyderabad
# 6         Kolkata Knight Riders               Mumbai Indians
# 7   Royal Challengers Bangalore              Kings XI Punjab
# 8              Delhi Daredevils       Rising Pune Supergiant
# 9           Sunrisers Hyderabad               Mumbai Indians
# 10              Kings XI Punjab        Kolkata Knight Riders
#
#                          winner
# 0           Sunrisers Hyderabad
# 1        Rising Pune Supergiant
# 2         Kolkata Knight Riders
# 3               Kings XI Punjab
# 4   Royal Challengers Bangalore
# 5           Sunrisers Hyderabad
# ...

# %%
ipl.loc[0,"team1"]
# Out:
# 'Sunrisers Hyderabad'

# %%
ipl.loc[0,"team1"]="Deccan Charger"

# %%
ipl.head(1)
# Out:
#    id  season       city        date           team1  \
# 0   1    2017  Hyderabad  2017-04-05  Deccan Charger
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
ipl.loc[0,"team1"]
# Out:
# 'Deccan Charger'

# %%
wnr=ipl["winner"]

# %%
wnr.head(10)
# Out:
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# 5            Sunrisers Hyderabad
# 6                 Mumbai Indians
# 7                Kings XI Punjab
# 8               Delhi Daredevils
# 9                 Mumbai Indians
# Name: winner, dtype: object

# %%
wnr.describe()
# Out:
# count                633
# unique                14
# top       Mumbai Indians
# freq                  92
# Name: winner, dtype: object

# %%
ipl.drop("umpire3",axis=1)
ipl.drop("player_of_match", axis=1)
ipl.drop("umpire1", axis=1)
ipl.drop("umpire2", axis=1)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
ipl.mean()
# Out:
# id                 318.500000
# season            2012.490566
# dl_applied           0.025157
# win_by_runs         13.682390
# win_by_wickets       3.372642
# umpire3                   NaN
# dtype: float64

# %%
ipl.median()
# Out:
# id                 318.5
# season            2012.0
# dl_applied           0.0
# win_by_runs          0.0
# win_by_wickets       4.0
# umpire3              NaN
# dtype: float64

# %%
ipl.mode()
# Out:
#       id  season    city        date           team1             team2  \
# 0      1  2013.0  Mumbai  2008-04-19  Mumbai Indians  Delhi Daredevils
# 1      2     NaN     NaN  2008-04-20             NaN               NaN
# 2      3     NaN     NaN  2008-04-26             NaN               NaN
# 3      4     NaN     NaN  2008-04-27             NaN               NaN
# 4      5     NaN     NaN  2008-05-01             NaN               NaN
# ..   ...     ...     ...         ...             ...               ...
# 631  632     NaN     NaN         NaN             NaN               NaN
# 632  633     NaN     NaN         NaN             NaN               NaN
# 633  634     NaN     NaN         NaN             NaN               NaN
# 634  635     NaN     NaN         NaN             NaN               NaN
# 635  636     NaN     NaN         NaN             NaN               NaN
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# ...

# %%
ipl.min()
# Out:
# id                                  1
# season                           2008
# date                       2008-04-18
# team1             Chennai Super Kings
# team2             Chennai Super Kings
# toss_winner       Chennai Super Kings
# toss_decision                     bat
# result                      no result
# dl_applied                          0
# win_by_runs                         0
# win_by_wickets                      0
# venue                Barabati Stadium
# umpire3                           NaN
# dtype: object

# %%
ipl.max()
# Out:
# id                                636
# season                           2017
# date                       2017-05-21
# team1             Sunrisers Hyderabad
# team2             Sunrisers Hyderabad
# toss_winner       Sunrisers Hyderabad
# toss_decision                   field
# result                            tie
# dl_applied                          1
# win_by_runs                       146
# win_by_wickets                     10
# venue                Wankhede Stadium
# umpire3                           NaN
# dtype: object

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.toss_winner.astype(str)
# Out:
# 0      Royal Challengers Bangalore
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633          Kolkata Knight Riders
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: toss_winner, Length: 636, dtype: object

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.sort_values('winner')
# Out:
#       id  season       city        date                        team1  \
# 70    71    2008    Chennai  2008-04-26        Kolkata Knight Riders
# 473  474    2014    Sharjah  2014-04-27          Sunrisers Hyderabad
# 210  211    2010    Chennai  2010-04-06          Chennai Super Kings
# 86    87    2008      Delhi  2008-05-08             Delhi Daredevils
# 546  547    2015    Chennai  2015-04-28          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 524  525    2015  Bangalore  2015-04-13  Royal Challengers Bangalore
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.drop(["id","date","result","dl_applied","player_of_match","venue","umpire1","umpire2","umpire3"], axis=1)
# Out:
#      season       city                        team1  \
# 0      2017  Hyderabad               Deccan Charger
# 1      2017       Pune               Mumbai Indians
# 2      2017     Rajkot                Gujarat Lions
# 3      2017     Indore       Rising Pune Supergiant
# 4      2017  Bangalore  Royal Challengers Bangalore
# ..      ...        ...                          ...
# 631    2016     Raipur             Delhi Daredevils
# 632    2016  Bangalore                Gujarat Lions
# 633    2016      Delhi          Sunrisers Hyderabad
# 634    2016      Delhi                Gujarat Lions
# 635    2016  Bangalore          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
ipl.to_csv('ipl2', index=False)

# %%
ipl2=pd.read_csv('ipl2')

# %%
ipl2
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05               Deccan Charger
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...
